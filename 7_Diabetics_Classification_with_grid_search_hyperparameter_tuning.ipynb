# %% [markdown]
# <a href="https://colab.research.google.com/github/rohailkhan/Deep-Learning-with-Python-Jb/blob/master/7_Diabetics_Classification_with_grid_search_hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation via sklearn
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import minmax_scale
import numpy as np
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['figure.dpi']=150

# %% [markdown]
# ## Example of 10-fold cross-validation with a Keras classifier

# %% [markdown]
# ### Function to create Keras model

# %%
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(30, input_dim=8, activation='relu'))
    model.add(Dense(15, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', 
                  optimizer='adam', 
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ### Load pima indians dataset

# %%
dataset = np.loadtxt("..\Data\pima-indian-diabetes.csv", delimiter=",",skiprows=1)

# %%
import pandas as pd

dataset =pd.read_csv("https://raw.githubusercontent.com/rohailkhan/data/main/diabetes.csv")

# %% [markdown]
# ### Split into input (X) and output (Y) variables, scale the X variables for better accuracy

# %%
X = dataset.iloc[:,0:8].astype('float')

# %%
Y = dataset.iloc[:,8].astype('float')

# %%
X_scaled = minmax_scale(X)

# %% [markdown]
# ### Create the model using `KerasClassifier` class
# Here, you pass on the `create_model` function, and other hyperparameters like epochs, and batch size.
#
# Later, we will see how to also pass on those hyperparameters to this class for a grid search.

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

model = KerasClassifier(build_fn=create_model, 
                        epochs=10, 
                        batch_size=32, 
                        verbose=0)

# %% [markdown]
# ### Evaluate using 10-fold cross validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

num_folds = 10
kfold = StratifiedKFold(n_splits=num_folds, 
                        shuffle=True)

# %%
cv_results = cross_val_score(model, 
                          X_scaled, Y, 
                          cv=kfold,
                          verbose=2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  ................................................................
# [CV] ................................................. , total=   1.9s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.2s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f7e1d35e290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f7e1d2ff560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] ................................................. , total=   1.1s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# [CV] ................................................. , total=   1.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   11.2s finished

# %% [markdown]
# ### Extract the mean and standard deviation of the cross-validation splits' scores

# %%
print(round(cv_results.mean(),3))
# Out:
# 0.678

# %%
print(round(cv_results.std(),3))
# Out:
# 0.035

# %% [markdown]
# ## Example of an exhaustive grid search with a Keras classifier

# %% [markdown]
# ### A model definition with extra arguments

# %%
def create_model_grid(activation = 'relu', 
                      optimizer='rmsprop', 
                      init='glorot_uniform'):
    # create model
    model = Sequential()
    
    if activation=='relu':
        model.add(Dense(12, input_dim=8, 
                        kernel_initializer=init, activation='relu'))
        model.add(Dense(8, kernel_initializer=init, activation='relu'))
    if activation=='tanh':
        model.add(Dense(12, input_dim=8, 
                        kernel_initializer=init, activation='tanh'))
        model.add(Dense(8, kernel_initializer=init, activation='tanh'))
    if activation=='sigmoid':
        model.add(Dense(12, input_dim=8, 
                        kernel_initializer=init, activation='sigmoid'))
        model.add(Dense(8, kernel_initializer=init, activation='sigmoid'))
    model.add(Dense(1, kernel_initializer=init, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    return model

# %%
model_grid = KerasClassifier(build_fn=create_model_grid, 
                             verbose=0)

# %% [markdown]
# ### Grid search epochs, batch size and optimizer
#
# We decide to make the exhaustive hyperparameter search space size as $3 \times 3 \times 3 \times 3 \times 3 = 243$
#
# Note that the **actual number of Keras runs will also depend on the number of cross-validation** we choose, as cross-validation will be used for each of these combinations.

# %%
activations = ['tanh','relu','sigmoid']
optimizers = ['rmsprop', 'adam','sgd']
initializers = ['glorot_uniform', 'normal', 'uniform']
epochs = [5,10,25]
batches = [8,16,64]

# %% [markdown]
# ### Create a dictionary of parameters and pass that to the `GridSearchCV` function as `param_grid`
# It is advisable to turn on verbosity at this stage to keep track of what's going on. Remember to keep the `verbose=0` for the main `KerasClassifier` class though, as you probably don't want to display all the gory details of training individual epcohs.
#
# By default, GridSearchCV runs a 3-fold corss-validation if the `cv` parameter is not specified explicitly. The number of cross-validation is going to change to 5 in the next v0.22 of scikit-learn.
#
# To know more about the Grid search function, see the following link: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %%
from sklearn.model_selection import GridSearchCV

param_grid = dict(activation =  activations,
                  optimizer=optimizers, 
                  epochs=epochs, 
                  batch_size=batches, 
                  init=initializers)

grid = GridSearchCV(estimator=model_grid, 
                    param_grid=param_grid,
                    cv = 3,
                    verbose=2,)

# %%
grid
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x7f7e14463e90>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'activation': ['tanh', 'relu', 'sigmoid'],
#                          'batch_size': [8, 16, 64], 'epochs': [5, 10, 25],
#                          'init': ['glorot_uniform', 'normal', 'uniform'],
#                          'optimizer': ['rmsprop', 'adam', 'sgd']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
Y
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0
#       ...
# 763    0.0
# 764    0.0
# 765    0.0
# 766    1.0
# 767    0.0
# Name: Outcome, Length: 768, dtype: float64

# %% [markdown]
# ### Fit (search) the grid
# This may take a while depending on the base model architecture, dataset size, and your hardware config.

# %%
grid_result = grid.fit(X_scaled, Y)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.8s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.4s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.8s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.6s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.8s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.4s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.8s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.7s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   1.0s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   2.1s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd, total=   2.2s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.9s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop, total=   1.5s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=rmsprop, total=   2.1s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam, total=   1.9s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=adam, total=   1.9s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd, total=   1.6s
# [CV] activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=normal, optimizer=sgd, total=   1.9s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop, total=   1.5s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop, total=   2.1s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam, total=   1.9s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam, total=   2.0s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=adam, total=   1.4s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd, total=   1.3s
# [CV] activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=10, init=uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   3.9s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   2.4s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   3.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd, total=   3.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd, total=   3.2s
# [CV] activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=glorot_uniform, optimizer=sgd, total=   3.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop, total=   2.4s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop, total=   3.8s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=rmsprop, total=   3.4s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam, total=   2.4s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=adam, total=   3.2s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd, total=   3.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd, total=   2.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=normal, optimizer=sgd, total=   3.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop, total=   3.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop, total=   2.5s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=rmsprop, total=   3.7s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam, total=   3.2s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd, total=   3.2s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd, total=   3.1s
# [CV] activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=8, epochs=25, init=uniform, optimizer=sgd, total=   2.1s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=5, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.6s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.3s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=adam, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.0s
# [CV] activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.7s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam, total=   1.3s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam, total=   1.1s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=adam, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=normal, optimizer=sgd, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop, total=   2.1s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop, total=   1.6s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=rmsprop, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam, total=   1.4s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=adam, total=   1.4s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd, total=   1.4s
# [CV] activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=10, init=uniform, optimizer=sgd, total=   1.2s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   2.3s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.0s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.0s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=adam, total=   2.2s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd, total=   2.1s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=glorot_uniform, optimizer=sgd, total=   2.1s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop, total=   3.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop, total=   3.8s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=rmsprop, total=   2.4s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam, total=   2.3s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=adam, total=   1.6s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd, total=   1.8s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=normal, optimizer=sgd, total=   1.8s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop, total=   1.7s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop, total=   2.1s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop, total=   1.7s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.5s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.8s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.9s
# [CV] activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   1.3s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.6s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   0.6s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.3s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   1.3s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.6s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   1.2s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   1.4s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   1.3s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   1.0s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   0.8s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=tanh, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.1s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=adam, total=   1.0s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=glorot_uniform, optimizer=sgd, total=   1.0s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.5s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.4s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=rmsprop, total=   1.1s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=adam, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=normal, optimizer=sgd, total=   0.9s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.9s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=rmsprop, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.0s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=adam, total=   1.3s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   1.2s
# [CV] activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=relu, batch_size=8, epochs=5, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   2.0s
# [CV] activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.5s
# [CV] activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=relu, batch_size=8, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   1.5s
# ...
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=rmsprop, total=   2.0s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.5s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.9s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=adam, total=   1.8s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.4s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.9s
# [CV] activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=16, epochs=25, init=uniform, optimizer=sgd, total=   1.4s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   1.2s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=glorot_uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   1.1s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   0.5s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=normal, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=rmsprop, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=5, init=uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=adam, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   1.1s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=glorot_uniform, optimizer=sgd, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=adam, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=normal, optimizer=sgd, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   1.3s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=adam, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.7s
# [CV] activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=10, init=uniform, optimizer=sgd, total=   0.6s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=rmsprop, total=   1.4s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=glorot_uniform, optimizer=sgd, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=rmsprop, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   1.4s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=adam, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=normal, optimizer=sgd, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.0s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=rmsprop, total=   1.1s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   1.2s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=adam, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   0.8s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   0.9s
# [CV] activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd
# [CV]  activation=sigmoid, batch_size=64, epochs=25, init=uniform, optimizer=sgd, total=   0.9s
# [Parallel(n_jobs=1)]: Done 729 out of 729 | elapsed: 16.8min finished

# %% [markdown]
# ### Print the best accuracy result

# %%
print("Best accuracy: {}\nBest combination: {}".format(grid_result.best_score_, 
                             grid_result.best_params_))
# Out:
# Best accuracy: 0.7643229166666666
# Best combination: {'activation': 'tanh', 'batch_size': 8, 'epochs': 25, 'init': 'glorot_uniform', 'optimizer': 'adam'}

# %% [markdown]
# ### Extract all the results (both mean and std. dev for the cross-validation runs)

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

# %% [markdown]
# ### Create a dataframe/table of all the runs with accuracy metric for analyzing later

# %%
import pandas as pd

# %%
d=pd.DataFrame(params)
d['Mean']=means
d['Std. Dev']=stds

# %%
param_ = ['batch_size','init','optimizer','activation']
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,2,figsize=(10,6), squeeze=False)
ax = ax.ravel()
for i in range(4):
    ax[i].set_title('Distribution of mean accuracy with {}'.format(param_[i]))
    sns.violinplot(x=param_[i],y='Mean',data=d,ax=ax[i])
fig.tight_layout(pad=1.5)

# %%
sns.catplot(x="activation", y="Mean", hue="optimizer", kind="swarm", data=d)
